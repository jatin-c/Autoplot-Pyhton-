# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:sh00j0000@localhost/flaskapp", echo=True)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# G:\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
query="select * from analysis;"
dfan=pd.read_sql(query, con=engine)
# Out:
# 2021-08-10 02:11:08,067 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-10 02:11:08,067 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 02:11:08,112 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-10 02:11:08,113 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 02:11:08,118 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-10 02:11:08,121 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 02:11:08,124 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-10 02:11:08,126 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 02:11:08,129 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-08-10 02:11:08,131 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 02:11:08,136 INFO sqlalchemy.engine.base.Engine DESCRIBE `select * from analysis;`
# 2021-08-10 02:11:08,139 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
dfan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11072 entries, 0 to 11071
# Data columns (total 11 columns):
# Agent Name                            11072 non-null object
# Date                                  11072 non-null object
# Active Screen Time                    11072 non-null float64
# Active Screen Time (Readable)         11070 non-null object
# Idle Time                             11072 non-null float64
# Idle Time (Readable)                  10585 non-null object
# Productive Screentime                 11072 non-null float64
# Productive Screentime (Readable)      11058 non-null object
# UnProductive Screentime               11072 non-null float64
# UnProductive Screentime (Readable)    9221 non-null object
# Report Description                    8 non-null object
# dtypes: float64(4), object(7)
# memory usage: 951.6+ KB

# %%
query="select * from attendence;"
dfat=pd.read_sql(query, con=engine)
# Out:
# 2021-08-10 18:08:03,549 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-10 18:08:03,549 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 18:08:03,817 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-10 18:08:03,817 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 18:08:03,865 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-10 18:08:03,865 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 18:08:03,901 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-10 18:08:03,901 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 18:08:03,909 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-08-10 18:08:03,909 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-10 18:08:03,917 INFO sqlalchemy.engine.base.Engine DESCRIBE `select * from attendence;`
# 2021-08-10 18:08:03,917 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
dfat
# Out:
#                Agent Name        Date First Login First Logout Last Login  \
# 0        CB-SPANJAL BASSI  01-07-2021    08:48:32     11:59:44   12:00:13
# 1                MF-SUMIT  01-07-2021    08:36:40     11:58:43   12:00:42
# 2        TFS-SUNITA YADAV  01-07-2021    08:49:48     11:58:16   12:01:20
# 3             MCARE-SAKET  01-07-2021    10:18:06     11:58:47   12:00:49
# 4       CB-SHIVANI KHANNA  01-07-2021    09:45:57     11:57:42   12:00:48
# ...                   ...         ...         ...          ...        ...
# 11065        MCARE-SUSHIL  31-07-2021    11:17:19     11:59:46   12:00:00
# 11066    CB-ANKIT PANCHAL  31-07-2021    11:50:48     11:59:57   12:00:01
# 11067  ME-PRAKASH-DESKTOP  31-07-2021    00:01:01     11:58:10   12:00:12
# 11068   CB-VIKASH DESKTOP  31-07-2021    00:00:28     11:57:59   12:00:02
# 11069   CB-PANKAJ KHANEJA  31-07-2021        None         None   22:21:22
#
#       Last Logout  Total Time(Hrs) Total Time (Readable)  \
# ...

# %%
dfat.describe()
# Out:
#        Total Time(Hrs)  Total Active Time(Hrs)
# count     11070.000000            11070.000000
# mean          6.583005                3.427183
# std           3.713074                2.234166
# min           0.000300                0.000300
# 25%           3.838600                1.616900
# 50%           7.075450                3.238600
# 75%           8.716400                4.926575
# max          23.614200               14.938100

# %%
desc=dfan.describe()

# %%
desc
# Out:
#        Active Screen Time     Idle Time  Productive Screentime  \
# count        11072.000000  11072.000000           11072.000000
# mean             3.426564      0.505151               3.266535
# std              2.234439      0.911026               2.185522
# min              0.000000      0.000000               0.000000
# 25%              1.616350      0.022800               1.498925
# 50%              3.238200      0.118300               3.061650
# 75%              4.925925      0.650375               4.737275
# max             14.938100     12.436400              14.724400
#
#        UnProductive Screentime
# count             11072.000000
# mean                  0.160029
# std                   0.280575
# min                   0.000000
# 25%                   0.006100
# 50%                   0.060000
# 75%                   0.187800
# max                   4.112500

# %% [markdown]
# # Correlation

# %% [markdown]
# #### Scatter plot
# #### Bubble plot with Encircling
# #### Scatter plot with line of best fit
# #### Jittering with stripplot
# #### Counts Plot
# #### Marginal Histogram
# #### Marginal Boxplot
# #### Correlogram
# #### Pairwise Plot

# %%
# Scatter plot
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# Prepare Data 
# Create as many colors as there are unique midwest['category']
categories = np.unique(midwest['category'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# Draw Plot for Each Category
plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')

for i, category in enumerate(categories):
    plt.scatter('area', 'poptotal', 
                data=midwest.loc[midwest.category==category, :], 
                s=20, c=colors[i], label=str(category))

# Decorations
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=22)
plt.legend(fontsize=12)    
plt.show()

# %% [markdown]
# ![scatterplot](https://www.machinelearningplus.com/wp-content/uploads/2018/11/1_Scatterplot_Matplotlib-min-865x541.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# # Deviation

# %% [markdown]
# #### Diverging Bars
# #### Diverging Texts
# #### Diverging Dot Plot
# #### Diverging Lollipop Chart with Markers
# #### Area Chart

# %%
# Prepare Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")
x = df.loc[:, ['mpg']]
df['mpg_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['mpg_z']]
df.sort_values('mpg_z', inplace=True)
df.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df.index, xmin=0, xmax=df.mpg_z, color=df.colors, alpha=0.4, linewidth=5)

# Decorations
plt.gca().set(ylabel='$Model$', xlabel='$Mileage$')
plt.yticks(df.index, df.cars, fontsize=12)
plt.title('Diverging Bars of Car Mileage', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ![Cat](https://www.machinelearningplus.com/wp-content/uploads/2018/11/10_Diverging_bars_Matplotlib-min-865x618.png?ezimgfmt=ng:webp/ngcb4 )

# %% [markdown]
# # Ranking

# %% [markdown]
# #### Ordered Bar Chart
# #### Lollipop Chart
# #### Dot Plot
# #### Slope Chart
# #### Dumbbell Plot

# %%
# ordered bar chart
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df = df_raw[['cty', 'manufacturer']].groupby('manufacturer').apply(lambda x: x.mean())
df.sort_values('cty', inplace=True)
df.reset_index(inplace=True)

# Draw plot
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(16,10), facecolor='white', dpi= 80)
ax.vlines(x=df.index, ymin=0, ymax=df.cty, color='firebrick', alpha=0.7, linewidth=20)

# Annotate Text
for i, cty in enumerate(df.cty):
    ax.text(i, cty+0.5, round(cty, 1), horizontalalignment='center')


# Title, Label, Ticks and Ylim
ax.set_title('Bar Chart for Highway Mileage', fontdict={'size':22})
ax.set(ylabel='Miles Per Gallon', ylim=(0, 30))
plt.xticks(df.index, df.manufacturer.str.upper(), rotation=60, horizontalalignment='right', fontsize=12)

# Add patches to color the X axis labels
p1 = patches.Rectangle((.57, -0.005), width=.33, height=.13, alpha=.1, facecolor='green', transform=fig.transFigure)
p2 = patches.Rectangle((.124, -0.005), width=.446, height=.13, alpha=.1, facecolor='red', transform=fig.transFigure)
fig.add_artist(p1)
fig.add_artist(p2)
plt.show()

# %% [markdown]
# ![orderedbarchart](https://www.machinelearningplus.com/wp-content/uploads/2018/11/15_Ordered_Barchart_Matplotlib-min-865x603.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# # Distribution

# %% [markdown]
# #### Histogram for Continuous Variable
# #### Histogram for Categorical Variable
# #### Density Plot
# #### Density Curves with Histogram
# #### Joy Plot
# #### Distributed Dot Plot
# #### Box Plot
# #### Dot + Box Plot
# #### Violin Plot
# #### Population Pyramid
# #### Categorical Plots

# %%
# Histogram for continuous variable
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare data
x_var = 'displ'
groupby_var = 'class'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 25)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()

# %% [markdown]
# ![continuous](https://www.machinelearningplus.com/wp-content/uploads/2018/11/20_Histogram_Continuous_Matplotlib-min-865x510.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# ![categorical](https://www.machinelearningplus.com/wp-content/uploads/2018/11/21_Histogram_Barchart_Matplotlib-min-865x582.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# # Composition

# %% [markdown]
# #### Waffle Chart
# #### Pie Chart
# #### Treemap
# #### Bar Chart

# %%
#! pip install pywaffle
# Reference: https://stackoverflow.com/questions/41400136/how-to-do-waffle-charts-in-python-square-piechart
from pywaffle import Waffle

# Import
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare Data
df = df_raw.groupby('class').size().reset_index(name='counts')
n_categories = df.shape[0]
colors = [plt.cm.inferno_r(i/float(n_categories)) for i in range(n_categories)]

# Draw Plot and Decorate
fig = plt.figure(
    FigureClass=Waffle,
    plots={
        '111': {
            'values': df['counts'],
            'labels': ["{0} ({1})".format(n[0], n[1]) for n in df[['class', 'counts']].itertuples()],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.05, 1), 'fontsize': 12},
            'title': {'label': '# Vehicles by Class', 'loc': 'center', 'fontsize':18}
        },
    },
    rows=7,
    colors=colors,
    figsize=(16, 9)
)

# %% [markdown]
# ![wafflechart](https://www.machinelearningplus.com/wp-content/uploads/2018/11/31_WaffleChart_1_Pywaffle-min-865x181.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# # Change

# %% [markdown]
# #### Time Series Plot
# #### Time Series with Peaks and Troughs Annotated
# #### Autocorrelation Plot
# #### Cross Correlation Plot
# #### Time Series Decomposition Plot
# #### Multiple Time Series
# #### Plotting with different scales using secondary Y axis
# #### Time Series with Error Bands
# #### Stacked Area Chart
# #### Area Chart Unstacked
# #### Calendar Heat Map
# #### Seasonal Plot

# %%
# time series plot
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')

# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('date', 'traffic', data=df, color='tab:red')

# Decoration
plt.ylim(50, 750)
xtick_location = df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in df.date.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Air Passengers Traffic (1949 - 1969)", fontsize=22)
plt.grid(axis='both', alpha=.3)

# Remove borders
plt.gca().spines["top"].set_alpha(0.0)    
plt.gca().spines["bottom"].set_alpha(0.3)
plt.gca().spines["right"].set_alpha(0.0)    
plt.gca().spines["left"].set_alpha(0.3)   
plt.show()

# %% [markdown]
# ![timeseries](https://www.machinelearningplus.com/wp-content/uploads/2018/11/35_TimeSeries_Matplotlib-min-865x541.png?ezimgfmt=ng:webp/ngcb4)

# %% [markdown]
# # Groups

# %% [markdown]
# #### Dendrogram
# #### Cluster Plot
# #### Andrews Curve
# #### Parallel Coordinates

# %%
# cluster plot
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial import ConvexHull

# Import Data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/USArrests.csv')

# Agglomerative Clustering
cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
cluster.fit_predict(df[['Murder', 'Assault', 'UrbanPop', 'Rape']])  

# Plot
plt.figure(figsize=(14, 10), dpi= 80)  
plt.scatter(df.iloc[:,0], df.iloc[:,1], c=cluster.labels_, cmap='tab10')  

# Encircle
def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    p = np.c_[x,y]
    hull = ConvexHull(p)
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)

# Draw polygon surrounding vertices    
encircle(df.loc[cluster.labels_ == 0, 'Murder'], df.loc[cluster.labels_ == 0, 'Assault'], ec="k", fc="gold", alpha=0.2, linewidth=0)
encircle(df.loc[cluster.labels_ == 1, 'Murder'], df.loc[cluster.labels_ == 1, 'Assault'], ec="k", fc="tab:blue", alpha=0.2, linewidth=0)
encircle(df.loc[cluster.labels_ == 2, 'Murder'], df.loc[cluster.labels_ == 2, 'Assault'], ec="k", fc="tab:red", alpha=0.2, linewidth=0)
encircle(df.loc[cluster.labels_ == 3, 'Murder'], df.loc[cluster.labels_ == 3, 'Assault'], ec="k", fc="tab:green", alpha=0.2, linewidth=0)
encircle(df.loc[cluster.labels_ == 4, 'Murder'], df.loc[cluster.labels_ == 4, 'Assault'], ec="k", fc="tab:orange", alpha=0.2, linewidth=0)

# Decorations
plt.xlabel('Murder'); plt.xticks(fontsize=12)
plt.ylabel('Assault'); plt.yticks(fontsize=12)
plt.title('Agglomerative Clustering of USArrests (5 Groups)', fontsize=22)
plt.show()

# %% [markdown]
# ![Cat](https://www.machinelearningplus.com/wp-content/uploads/2018/11/48_Cluster_Plot_Matplotlib-min-865x618.png?ezimgfmt=ng:webp/ngcb4)

# %%
import json
from dataprofiler import Data, Profiler

# %%
profile = Profiler(dfan) # Calculate Statistics, Entity Recognition, etc

readable_report = profile.report(report_options={"output_format": "compact"})

print(json.dumps(readable_report, indent=4))
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...  (with 3 processes)
# C:\Users\jatin c\AppData\Roaming\Python\Python37\site-packages\dataprofiler\profilers\profile_builder.py:1962: UserWarning: The data will be profiled with a sample size of 5000. All statistics will be based on this subsample and not the whole dataset.
#   "not the whole dataset.".format(sample_size))
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:05<00:00,  2.17it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...  (with 4 processes)
# ...

# %%
out_file = open("myfile.json", "w") 
    
json.dump(readable_report, out_file, indent = 6) 
    
out_file.close()

# %%
out_file = open("creditcard.json", "w") 
    
json.dump(readable_report, out_file, indent = 6) 
    
out_file.close()

# %%
readable_report
# Out:
# {'global_stats': {'samples_used': 5000,
#   'column_count': 11,
#   'row_count': 11072,
#   'row_has_null_ratio': 0.9998,
#   'row_is_null_ratio': 0.0,
#   'unique_row_ratio': 1.0,
#   'duplicate_row_count': 0,
#   'file_type': "<class 'pandas.core.frame.DataFrame'>",
#   'encoding': None,
#   'correlation_matrix': None,
#   'profile_schema': defaultdict(list,
#               {'Agent Name': [0],
#                'Date': [1],
#                'Active Screen Time': [2],
#                'Active Screen Time (Readable)': [3],
#                'Idle Time': [4],
#                'Idle Time (Readable)': [5],
#                'Productive Screentime': [6],
#                'Productive Screentime (Readable)': [7],
#                'UnProductive Screentime': [8],
#                'UnProductive Screentime (Readable)': [9],
#                'Report Description': [10]}),
#   'times': {'row_stats': 0.1875}},
#  'data_stats': [{'column_name': 'Agent Name',
#    'data_type': 'string',
# ...

# %%
df_card=pd.read_excel('Data Set.xlsx')

# %%
profile = Profiler(df_card) # Calculate Statistics, Entity Recognition, etc

readable_report = profile.report(report_options={"output_format": "compact"})
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...  (with 3 processes)
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [00:23<00:00,  5.49it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...  (with 4 processes)
#   2%|█▎                                                                                | 2/130 [00:06<05:57,  2.80s/it]
# ...

# %%
readable_report
# Out:
# {'global_stats': {'samples_used': 5000,
#   'column_count': 130,
#   'row_count': 5000,
#   'row_has_null_ratio': 0.8844,
#   'row_is_null_ratio': 0.0,
#   'unique_row_ratio': 1.0,
#   'duplicate_row_count': 0,
#   'file_type': "<class 'pandas.core.frame.DataFrame'>",
#   'encoding': None,
#   'correlation_matrix': None,
#   'profile_schema': defaultdict(list,
#               {'custid': [0],
#                'region': [1],
#                'townsize': [2],
#                'gender': [3],
#                'age': [4],
#                'agecat': [5],
#                'birthmonth': [6],
#                'ed': [7],
#                'edcat': [8],
#                'jobcat': [9],
#                'union': [10],
#                'employ': [11],
#                'empcat': [12],
#                'retire': [13],
#                'income': [14],
#                'lninc': [15],
#                'inccat': [16],
#                'debtinc': [17],
#                'creddebt': [18],
# ...

# %%
import json
from dataprofiler import Data, Profiler

data = Data("Data Set.xlsx") # Auto-Detect & Load: CSV, AVRO, Parquet, JSON, Text, URL

print(data.data.head(5)) # Access data directly via a compatible Pandas DataFrame

# profile = Profiler(data) # Calculate Statistics, Entity Recognition, etc

# readable_report = profile.report(report_options={"output_format": "compact"})

# print(json.dumps(readable_report, indent=4))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-fb95cb0d46e4> in <module>
#       2 from dataprofiler import Data, Profiler
#       3
# ----> 4 data = Data("Data Set.xlsx") # Auto-Detect & Load: CSV, AVRO, Parquet, JSON, Text, URL
#       5
#       6 print(data.data.head(5)) # Access data directly via a compatible Pandas DataFrame
#
# ~\AppData\Roaming\Python\Python37\site-packages\dataprofiler\data_readers\data.py in __new__(cls, input_file_path, data, data_type, options)
#      65             options_copy.update(kwargs)
#      66             if (not data_type or data_type == data_class.data_type) and \
# ---> 67                    (data is not None or data_class.is_match(input_file_path, options_copy)):
#      68                 return data_class(input_file_path, data, options_copy)
#      69
#
# ...

# %%
import json
from dataprofiler import Data, Profiler
dftrans=pd.read_csv("Transactions.csv")
profile = Profiler(dftrans) # Calculate Statistics, Entity Recognition, etc

readable_report = profile.report(report_options={"output_format": "compact"})

readable_report
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...  (with 3 processes)
# C:\Users\jatin c\AppData\Roaming\Python\Python37\site-packages\dataprofiler\profilers\profile_builder.py:1962: UserWarning: The data will be profiled with a sample size of 5000. All statistics will be based on this subsample and not the whole dataset.
#   "not the whole dataset.".format(sample_size))
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.05it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...  (with 4 processes)
# ...

# %%
out_file = open("transactions.json", "w") 
    
json.dump(readable_report, out_file, indent = 6) 
    
out_file.close()

# %%
data_stats=readable_report['data_stats']

# %%
data_stats[0]['statistics']
# Out:
# {'min': 10861359.0,
#  'max': 99986751618.0,
#  'mode': '[4.27505544e+10]',
#  'sum': 249383012461167.0,
#  'mean': 49876602492.2334,
#  'variance': 8.531120353553383e+20,
#  'stddev': 29208081678.798,
#  'skewness': 0.0061,
#  'kurtosis': -1.2243,
#  'quantiles': {0: 24238352098.431, 1: 49987698056.249, 2: 75405179600.5683},
#  'num_zeros': 0,
#  'num_negatives': 0,
#  'unique_count': 4898,
#  'unique_ratio': 0.9796,
#  'sample_size': 5000,
#  'null_count': 0,
#  'null_types': '[]',
#  'data_type_representation': {'datetime': 0.0,
#   'int': 1.0,
#   'float': 1.0,
#   'string': 1.0}}

# %%
for i in data_stats:
    print(i)
# Out:
# {'column_name': 'transaction_id', 'data_type': 'int', 'data_label': 'BAN', 'categorical': False, 'order': 'random', 'samples': "['46384532177', '52342659186', '32756320979', '53429613204', '39185908168']", 'statistics': {'min': 10861359.0, 'max': 99986751618.0, 'mode': '[4.27505544e+10]', 'sum': 249383012461167.0, 'mean': 49876602492.2334, 'variance': 8.531120353553383e+20, 'stddev': 29208081678.798, 'skewness': 0.0061, 'kurtosis': -1.2243, 'quantiles': {0: 24238352098.431, 1: 49987698056.249, 2: 75405179600.5683}, 'num_zeros': 0, 'num_negatives': 0, 'unique_count': 4898, 'unique_ratio': 0.9796, 'sample_size': 5000, 'null_count': 0, 'null_types': '[]', 'data_type_representation': {'datetime': 0.0, 'int': 1.0, 'float': 1.0, 'string': 1.0}}}
# ...

# %%
row_count=readable_report['global_stats']['row_count']
row_count
# Out:
# 23053

# %%
readable_report
# Out:
# {'global_stats': {'samples_used': 5000,
#   'column_count': 10,
#   'row_count': 23053,
#   'row_has_null_ratio': 0.0,
#   'row_is_null_ratio': 0.0,
#   'unique_row_ratio': 0.9994,
#   'duplicate_row_count': 13,
#   'file_type': "<class 'pandas.core.frame.DataFrame'>",
#   'encoding': None,
#   'correlation_matrix': None,
#   'profile_schema': defaultdict(list,
#               {'transaction_id': [0],
#                'cust_id': [1],
#                'tran_date': [2],
#                'prod_subcat_code': [3],
#                'prod_cat_code': [4],
#                'Qty': [5],
#                'Rate': [6],
#                'Tax': [7],
#                'total_amt': [8],
#                'Store_type': [9]}),
#   'times': {'row_stats': 0.0781}},
#  'data_stats': [{'column_name': 'transaction_id',
#    'data_type': 'int',
#    'data_label': 'BAN',
#    'categorical': False,
#    'order': 'random',
# ...

# %%
global_stats=readable_report['global_stats']

# %%
cat_stats={}
a={}

num_stats={}
b={}
for i, j in zip(data_stats,global_stats):
    if i['categorical']==True:
        a['column_name']=i['column_name']
        a['data_type']=i['data_type']
        a['order']=i['order']
        #cat_stats['unique_count']=i['unique_count']
        a['data_label']=i['data_label']
        a['mean']=i['statistics']['mean']
        a['variance']=i['statistics']['variance']
        a['null_count']=i['statistics']['null_count']
        a['unique_count']=i['statistics']['unique_count']
        a['stddev']=i['statistics']['stddev']
        b=a.copy()
        cat_stats.update(b)
        
    else:
        a['column_name']=i['column_name']
        a['data_type']=i['data_type']
        a['order']=i['order']
        #num_stats['unique_count']=i['unique_count']
        a['data_label']=i['data_label']
        a['mean']=i['statistics']['mean']
        a['variance']=i['statistics']['variance']
        a['null_count']=i['statistics']['null_count']
        a['unique_count']=i['statistics']['unique_count']
        a['stddev']=i['statistics']['stddev']
        b=a.copy()
        num_stats.update(b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-190d89299663> in <module>
#      25         #num_stats['unique_count']=i['unique_count']
#      26         a['data_label']=i['data_label']
# ---> 27         a['mean']=i['statistics']['mean']
#      28         a['variance']=i['statistics']['variance']
#      29         a['null_count']=i['statistics']['null_count']
#
# KeyError: 'mean'

# %%
data_stats
# Out:
# [{'column_name': 'transaction_id',
#   'data_type': 'int',
#   'data_label': 'BAN',
#   'categorical': False,
#   'order': 'random',
#   'samples': "['45903192635', '53314349706', '10319624627', '29936370996', '24188542835']",
#   'statistics': {'min': 7073244.0,
#    'max': 99986751618.0,
#    'mode': '[5.34462113e+10, 8.25402977e+10]',
#    'sum': 250613669200311.0,
#    'mean': 50122733840.0622,
#    'variance': 8.329421566870733e+20,
#    'stddev': 28860737285.9231,
#    'skewness': 0.0077,
#    'kurtosis': -1.2059,
#    'quantiles': {0: 25261940001.2724, 1: 50130218668.832, 2: 75541720255.557},
#    'num_zeros': 0,
#    'num_negatives': 0,
#    'unique_count': 4902,
#    'unique_ratio': 0.9804,
#    'sample_size': 5000,
#    'null_count': 0,
#    'null_types': '[]',
#    'data_type_representation': {'datetime': 0.0,
#     'int': 1.0,
#     'float': 1.0,
#     'string': 1.0}}},
#  {'column_name': 'cust_id',
#   'data_type': 'datetime',
#   'data_label': 'INTEGER|TIME',
# ...

# %%
cat_stats
# Out:
# {'column_name': 'Store_type',
#  'data_type': 'string',
#  'order': 'random',
#  'data_label': 'UNKNOWN',
#  'mean': 7.3306,
#  'variance': 13.0979,
#  'null_count': 0,
#  'unique_count': 4,
#  'stddev': 3.6191}

# %%
for i in data_stats:
    print(i['categorical'])
    print(i['statistics']['num_zeros'])
# Out:
# False
# 0
# False
# 0
# False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d163bf390cfc> in <module>
#       1 for i in data_stats:
#       2     print(i['categorical'])
# ----> 3     print(i['statistics']['num_zeros'])
#
# KeyError: 'num_zeros'

# %%
import json
from dataprofiler import Data, Profiler

# %%
def dyn_plot(df, flag):
    profile = Profiler(dftrans) # Calculate Statistics, Entity Recognition, etc
    readable_report = profile.report(report_options={"output_format": "compact"})

# %%
df profiler(count_json):
    if no_column==1:
        (distribution charts)
    elif no_column==2:
        if both continous:
            scatterplot
            pairplot
        elif both categorical:
            frequency bars
        else:
            stacked bars
            pairplot with hue
    elif no_column==3:
        if one categorical and rest num:
            
        
    elif no_column==4:
        
    else:
        print("Can't visualize more than 4 dimensions")

# %%
def counts(df):
    c_count=0
    c_name=[]
    n_count=0
    n_name=[]
    count_json={}
    count_json['no_column']=df.shape[1]

    for i in data_stats:
        if i['categorical']==True:
            c_count+=1
            c_name.append(i['column_name'])

        else:
            n_count+=1
            n_name.append(i['column_name'])
    if c_count and c_name:
        count_json['c_count']=c_count
        count_json['c_name']=c_name
    else:
        count_json['c_count']=False
        count_json['c_name']=False
    if n_count and n_name:
        count_json['n_name']=n_name
        count_json=['n_count']=n_count
    else:
        count_json['n_name']=False
        count_json=['n_count']=False
    return count_json
# Out:
# 4
#  6
# ['prod_subcat_code', 'prod_cat_code', 'Qty', 'Store_type'] ['transaction_id', 'cust_id', 'tran_date', 'Rate', 'Tax', 'total_amt']

# %%
data_stats
# Out:
# [{'column_name': 'transaction_id',
#   'data_type': 'int',
#   'data_label': 'BAN',
#   'categorical': False,
#   'order': 'random',
#   'samples': "['45903192635', '53314349706', '10319624627', '29936370996', '24188542835']",
#   'statistics': {'min': 7073244.0,
#    'max': 99986751618.0,
#    'mode': '[5.34462113e+10, 8.25402977e+10]',
#    'sum': 250613669200311.0,
#    'mean': 50122733840.0622,
#    'variance': 8.329421566870733e+20,
#    'stddev': 28860737285.9231,
#    'skewness': 0.0077,
#    'kurtosis': -1.2059,
#    'quantiles': {0: 25261940001.2724, 1: 50130218668.832, 2: 75541720255.557},
#    'num_zeros': 0,
#    'num_negatives': 0,
#    'unique_count': 4902,
#    'unique_ratio': 0.9804,
#    'sample_size': 5000,
#    'null_count': 0,
#    'null_types': '[]',
#    'data_type_representation': {'datetime': 0.0,
#     'int': 1.0,
#     'float': 1.0,
#     'string': 1.0}}},
#  {'column_name': 'cust_id',
#   'data_type': 'datetime',
#   'data_label': 'INTEGER|TIME',
# ...

# %%
dftrans.shape[1]
# Out:
# 10

# %% [markdown]
# if all vars is continous
#    scatter plot
#    histogram
#    pie chart
#    stacked chart
#    pairplot
# if one cat and one num
#    grouped bar
# if multiple cat and multiple num
#    pairplot
#    grouped stacked
# if all categorical
#    frequency distribution bars

# %%
import pandas as pd

# %%
dftrans=pd.read_csv("Transactions.csv")

# %%
dftrans
# Out:
# C:\Users\jatin c\AppData\Roaming\Python\Python37\site-packages\lux\executor\PandasExecutor.py:462: UserWarning:
# Lux detects that the attribute 'tran_date' may be temporal.
# To display visualizations for these attributes accurately, please convert temporal attributes to Datetime objects.
# For example, you can convert a Year attribute (e.g., 1998, 1971, 1982) using pd.to_datetime by specifying the `format` as '%Y'.
#
# Here is a starter template that you can use for converting the temporal fields:
# 	df['tran_date'] = pd.to_datetime(df['tran_date'], format='<replace-with-datetime-format>')
#
# See more at: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
# If tran_date is not a temporal attribute, please use override Lux's automatically detected type:
# 	df.set_data_type({'tran_date':'quantitative'})
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
a="abc xyz ERROR1"

dftrans.endswith("ERROR")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-44d0a5360951> in <module>
#       1 a="abc xyz ERROR1"
#       2
# ----> 3 dftrans.endswith("ERROR")
#
# ~\AppData\Roaming\Python\Python37\site-packages\lux\core\frame.py in __getattr__(self, name)
#     172     #####################
#     173     def __getattr__(self, name):
# --> 174         ret_value = super(LuxDataFrame, self).__getattr__(name)
#     175         self.expire_metadata()
#     176         self.expire_recs()
#
# G:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
a={"error":"sffdf"}
print(type(a))
print(type(a['error']))
# Out:
# <class 'dict'>
# <class 'str'>

# %%
type(dftrans)
# Out:
# lux.core.frame.LuxDataFrame

# %%
from pywaffle import Waffle
import pandas as pd
import matplotlib.pyplot as plt

# Import
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare Data
df = df_raw.groupby('class').size().reset_index(name='counts')
n_categories = df.shape[0]
colors = [plt.cm.inferno_r(i/float(n_categories)) for i in range(n_categories)]

# Draw Plot and Decorate
fig = plt.figure(
    FigureClass=Waffle,
    plots={
        '111': {
            'values': df['counts'],
            'labels': ["{0} ({1})".format(n[0], n[1]) for n in df[['class', 'counts']].itertuples()],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.05, 1), 'fontsize': 12},
            'title': {'label': '# Vehicles by Class', 'loc': 'center', 'fontsize':18}
        },
    },
    rows=7,
    colors=colors,
    figsize=(16, 9)
)

plt.savefig('waffle.png',bbox_inches='tight')
# Out:
# <Waffle size 1152x648 with 1 Axes>

# %%
colors
# Out:
# [(0.988362, 0.998364, 0.644924, 1.0),
#  (0.981173, 0.759135, 0.156863, 1.0),
#  (0.961293, 0.488716, 0.084289, 1.0),
#  (0.832299, 0.283913, 0.257383, 1.0),
#  (0.621685, 0.164184, 0.388781, 1.0),
#  (0.397674, 0.083257, 0.433183, 1.0),
#  (0.15585, 0.044559, 0.325338, 1.0)]

# %%
df_raw.groupby('class').size()
# Out:
# class
# 2seater        5
# compact       47
# midsize       41
# minivan       11
# pickup        33
# subcompact    35
# suv           62
# dtype: int64

# %%
df_raw['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %%
class
2seater        5
compact       47
midsize       41
minivan       11
pickup        33
subcompact    35
suv

# %%
df_raw
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df
# Out:
#         class  counts
# 0     2seater       5
# 1     compact      47
# 2     midsize      41
# 3     minivan      11
# 4      pickup      33
# 5  subcompact      35
# 6         suv      62

# %%
import numpy as np
np.random.seed(23685752)
N_points = 10000
n_bins = 20

# Creating distribution
x = np.random.randn(N_points)
y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)



# Creating histogram
N, bins, patches = axs.hist(x, bins = n_bins)

# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())

for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

# Adding extra features   
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e41fc5273172> in <module>
#      39 # Setting color
#      40 fracs = ((N**(1 / 5)) / N.max())
# ---> 41 norm = colors.Normalize(fracs.min(), fracs.max())
#      42
#      43 for thisfrac, thispatch in zip(fracs, patches):
#
# AttributeError: 'list' object has no attribute 'Normalize'

# %%
# Import Data
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')

# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('date', 'traffic', data=df, color='tab:red')

# Decoration
plt.ylim(50, 750)
xtick_location = df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in df.date.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Air Passengers Traffic (1949 - 1969)", fontsize=22)
plt.grid(axis='both', alpha=.3)

# Remove borders
plt.gca().spines["top"].set_alpha(0.0)    
plt.gca().spines["bottom"].set_alpha(0.3)
plt.gca().spines["right"].set_alpha(0.0)    
plt.gca().spines["left"].set_alpha(0.3)   
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-dc4c5e867cfb> in <module>
#       4 # Draw Plot
#       5 plt.figure(figsize=(16,10), dpi= 80)
# ----> 6 plt.plot('date', 'traffic', data=df, color='tab:red')
#       7
#       8 # Decoration
#
# G:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# G:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %%
df
# Out:
#            date  value
# 0    1949-01-01    112
# 1    1949-02-01    118
# 2    1949-03-01    132
# 3    1949-04-01    129
# 4    1949-05-01    121
# ..          ...    ...
# 139  1960-08-01    606
# 140  1960-09-01    508
# 141  1960-10-01    461
# 142  1960-11-01    390
# 143  1960-12-01    432
#
# [144 rows x 2 columns]

# %%
df.index.tolist()[::12]
# Out:
# [0, 12, 24, 36, 48, 60, 72, 84, 96, 108, 120, 132]

# %%
df.date
# Out:
# 0      1949-01-01
# 1      1949-02-01
# 2      1949-03-01
# 3      1949-04-01
# 4      1949-05-01
#           ...
# 139    1960-08-01
# 140    1960-09-01
# 141    1960-10-01
# 142    1960-11-01
# 143    1960-12-01
# Name: date, Length: 144, dtype: object

# %%
xtick_labels = [x[-4:] for x in df.date.tolist()[::12]]

# %%
xtick_labels
# Out:
# ['1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01',
#  '1-01']

# %%
d={}
d['a']='f'
d['e']='r'
d['r']=False
d['b']=False

# %%
d
# Out:
# {'a': 'f', 'e': 'r', 'r': False, 'b': False}

# %%
# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20

# Creating distribution
x = np.random.randn(N_points)
y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)



# Creating histogram
N, bins, patches = axs.hist(x, bins = n_bins)

# # Setting color
# fracs = ((N**(1 / 5)) / N.max())
# norm = colors.Normalize(fracs.min(), fracs.max())

# for thisfrac, thispatch in zip(fracs, patches):
#     color = plt.cm.viridis(norm(thisfrac))
#     thispatch.set_facecolor(color)

# Adding extra features   
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')

# Show plot
plt.show()

# %%
dft=pd.read_csv('transactions.csv')

# %%
dft
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
n_bins=20
# Creating distribution
x = dft['total_amt']
#y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)



# Creating histogram
N, bins, patches = axs.hist(x, bins = n_bins)

plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')

# Show plot
plt.show()

# %%
plt.scatter(dft.index, dft['total_amt'])
plt.show()

# %%
n = dft['Store_type'].unique().__len__()+1

# %%
dft['Store_type'].unique().__len__()
# Out:
# 4

# %%
dft
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
def scatterplot(df, count_json):
    cat_name=count_json['c_name'][0]
    categories = np.unique(df[cat_name])
    colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

    # Draw Plot for Each Category
    plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')

    for i, category in enumerate(categories):
        plt.scatter(count_json['n_name'][0], count_json['n_name'][1], 
                    data=midwest.loc[midwest.category==category, :], 
                    s=20, c=colors[i], label=str(category))
    # Decorations
    plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
                xlabel='Area', ylabel='Population')
    plt.xticks(fontsize=12); plt.yticks(fontsize=12)
    plt.legend(fontsize=12)    
    plt.show()

# %%
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# Prepare Data 
# Create as many colors as there are unique midwest['category']
categories = np.unique(midwest['category'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# Draw Plot for Each Category
plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')

for i, category in enumerate(categories):
    plt.scatter('area', 'poptotal', 
                data=midwest.loc[midwest.category==category, :], 
                s=20, c=colors[i], label=str(category))

# Decorations
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=22)
plt.legend(fontsize=12)    
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
#midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")
sns.scatterplot(data=midwest, x="popwhite", y="popblack", hue="state", style="state")
plt.savefig("scatt.png",bbox_inches='tight')

# %%
midwest['category'].value_counts()
# Out:
# AAR    186
# LAR     30
# LHR     27
# AAU     21
# AHR     16
# ALU     14
# ALR     11
# HLU     10
# HAR      6
# HAU      3
# LAU      3
# HLR      2
# LHU      2
# HHR      1
# Name: category, dtype: int64

# %%
max(midwest[midwest['state']=='IL']['popasian'])
# Out:
# 2178

# %%
#for i in midwest.columns:
#    print(midwest[i].dtype)
ty=str(midwest['state'].dtype)    
ty
# Out:
# 'object'

# %%
query="select * from analysis"
dfg=pd.read_sql(query, con=engine)
dfg.dtypes
# Out:
# 2021-08-19 16:02:01,511 INFO sqlalchemy.engine.base.OptionEngine select * from analysis
# 2021-08-19 16:02:01,536 INFO sqlalchemy.engine.base.OptionEngine {}
# Agent Name                             object
# Date                                   object
# Active Screen Time                    float64
# Active Screen Time (Readable)          object
# Idle Time                             float64
# Idle Time (Readable)                   object
# Productive Screentime                 float64
# Productive Screentime (Readable)       object
# UnProductive Screentime               float64
# UnProductive Screentime (Readable)     object
# Report Description                     object
# dtype: object

# %%
midwest.dtypes
# Out:
# PID                       int64
# county                   object
# state                    object
# area                    float64
# poptotal                  int64
# popdensity              float64
# popwhite                  int64
# popblack                  int64
# popamerindian             int64
# popasian                  int64
# popother                  int64
# percwhite               float64
# percblack               float64
# percamerindan           float64
# percasian               float64
# percother               float64
# popadults                 int64
# perchsd                 float64
# percollege              float64
# percprof                float64
# poppovertyknown           int64
# percpovertyknown        float64
# percbelowpoverty        float64
# percchildbelowpovert    float64
# percadultpoverty        float64
# percelderlypoverty      float64
# inmetro                   int64
# category                 object
# dot_size                float64
# ...

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 327  3045   WALWORTH    WI  0.032     75000  2343.750000     72747       454
# 328  3046   WASHBURN    WI  0.050     13772   275.440000     13585        25
# 329  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 330  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 331  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# %%
# Import Data
#df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare data
x_var = 'category'
groupby_var = 'state'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(16,9), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, df[x_var].unique().__len__(), stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])})
plt.title(f"Stacked Histogram of ${x_var}$ colored by ${groupby_var}$", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 40)
#plt.xticks(ticks=bins, labels=np.unique(df[x_var]).tolist(), rotation=90, horizontalalignment='left')
plt.show()

# %%
n=['none','None']
a='naone'
a not in n
# Out:
# True

# %%
vals
# Out:
# [['AAR',
#   'LHR',
#   'AAR',
#   'ALU',
#   'AAR',
#   'AAR',
#   'LAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'LAR',
#   'LAU',
#   'AAR',
#   'AAR',
#   'AAR',
#   'HAU',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'LHR',
#   'AAR',
#   'LHR',
#   'AAR',
#   'ALU',
#   'LHR',
#   'AAR',
#   'LHR',
#   'AAR',
#   'AAU',
#   'AAR',
#   'AHR',
#   'AAR',
#   'AAR',
#   'AAU',
#   'AAR',
#   'LAR',
#   'HLU',
#   'AAR',
#   'AHR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'HHR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'LAR',
#   'AAU',
#   'AAR',
#   'ALU',
#   'AAR',
#   'AAR',
#   'AAR',
#   'ALU',
#   'LAR',
#   'HLR',
#   'AHR',
#   'LHR',
#   'LHR',
#   'AAR',
#   'LAR',
#   'AAR',
#   'LHR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'AAR',
#   'LHR',
#   'AAR',
#   'AAR',
#   'LAR',
#   'LAR',
#   'LHR',
#   'AAR',
#   'AAR',
#   'HLU'],
#  ['AAU',
#   'AAR',
#   'AAR',
#   'AAR',
#   'HLU',
#   'ALR',
#   'AAR',
# ...

# %%
dfgg = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
#df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
dfgg.loc[:, ['manufacturer', 'class']].groupby('class')

# %%
res=midwest[['popblack','popwhite']].groupby(midwest['state'])

# %%
midwest.set_index('state', inplace=True)
fig, ax = plt.subplots(1, figsize=(16, 8))
plt.rc('xtick', labelsize=13)
x = np.arange(0, len(df.index))
plt.bar(x - 0.3, df[count_json['n_name'][0]], width = 0.4, color = '#BC8F8F')
plt.bar(x - 0.1, df[count_json['n_name'][1]], width = 0.4, color = '#8B4513')
plt.bar(x + 0.1, df[count_json['n_name'][2]], width = 0.4, color = '#708090')
#plt.bar(x + 0.3, df_grouped['Other_Sales'], width = 0.2, color = '#FAC748')
# remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# x y details
plt.xticks(x, df.index)
plt.xlim(-0.5, 6.5)
# grid lines
ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed', alpha=0.2)
# title and legend
plt.legend([count_json['n_name'][0], count_json['n_name'][1], count_json['n_name'][2]], loc='upper left', ncol = 4)
plt.show()
#fig=res1.plot(kind="bar",stacked=True)
#filepath_stacked="G:/VScode workspace/Autoplot/{path}".format(path=str(uuid.uuid1())+"stacked.png")
# now_time=datetime.now().time()
# time=now_time.strftime('%I_%M_%S')
# filename=str(time)+"stacked.png"
# fig.savefig(SAVEPATH+filename ,bbox_inches='tight')
# plt.clf()

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 327  3045   WALWORTH    WI  0.032     75000  2343.750000     72747       454
# 328  3046   WASHBURN    WI  0.050     13772   275.440000     13585        25
# 329  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 330  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 331  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# %%
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 327  3045   WALWORTH    WI  0.032     75000  2343.750000     72747       454
# 328  3046   WASHBURN    WI  0.050     13772   275.440000     13585        25
# 329  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 330  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 331  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest.loc[midwest.category==category, :]
# Out:
#       PID    county state   area  poptotal  popdensity  popwhite  popblack  \
# 140   734     SCOTT    IN  0.011     20991  1908.27273     20850        16
# 249  2052  LAWRENCE    OH  0.026     61834  2378.23077     60115      1559
#
#      popamerindian  popasian  ...  percprof  poppovertyknown  \
# 140             25        50  ...  3.277182            20636
# 249             57        75  ...  3.146434            61007
#
#      percpovertyknown  percbelowpoverty  percchildbelowpovert  \
# 140         98.308799         18.981392             26.882281
# 249         98.662548         23.539922             33.230002
#
#      percadultpoverty  percelderlypoverty  inmetro  category    dot_size
# 140         15.887214           16.083916        1       LHU  332.062234
# 249         21.106436           16.387527        1       LHU  391.879124
#
# [2 rows x 29 columns]

# %%
dft=pd.read_csv('Transactions.csv')

# %%
dft
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
dft.set_index('Store_type', inplace=True)
fig, ax = plt.subplots(1, figsize=(16, 8))
plt.rc('xtick', labelsize=13) 
x = np.arange(0, len(dft.index))
plt.bar(x - 0.3, dft['Tax'], width = 0.4, color = '#BC8F8F')
#plt.bar(x + 0.3, df_grouped['Other_Sales'], width = 0.2, color = '#FAC748')
# remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# x y details
plt.ylabel('total_amt')
plt.xticks(x, dft.index)
plt.xlim(-0.5, 6.5)
# grid lines
ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed', alpha=0.2)
fig=plt.show()

# %%
dft.index
# Out:
# Index(['e-Shop', 'e-Shop', 'TeleShop', 'e-Shop', 'TeleShop', 'TeleShop',
#        'e-Shop', 'TeleShop', 'MBR', 'e-Shop',
#        ...
#        'e-Shop', 'e-Shop', 'TeleShop', 'e-Shop', 'TeleShop', 'e-Shop',
#        'e-Shop', 'MBR', 'TeleShop', 'TeleShop'],
#       dtype='object', name='Store_type', length=23053)

# %%
def fun(x):
    try:
        print("Yay! I still got executed, even though my function has already returned!")
        
    finally:
        return x * 20

# %%
print(fun(2))
# Out:
# Yay! I still got executed, even though my function has already returned!
# 40

# %%
midwest.to_csv("midwest.csv")

# %%
sr=dft[dft['Store_type']=='TeleShop']
sr.empty
# Out:
# False

# %%
from datetime import datetime, date, timedelta
today = date.today()
yr = today.year
mn= today.month

yesterday = today - timedelta(days = 1)
yes_mon=yesterday.month
yes_year=yesterday.year
prev_dt=[yesterday.strftime('%d-%m-%Y')]

# %%
prev_dt
# Out:
# ['15-08-2021']

# %%
today = datetime.utcnow().date()

# %%
today.month
# Out:
# 8

# %%
prev=today-timedelta(days=1)
prev.strftime("%d-%m-%Y")
# Out:
# '15-08-2021'

# %%
from datetime import datetime, timezone
import time

datetimeObject = datetime.fromtimestamp(time.time(), timezone.utc)
print(datetimeObject.strftime("%d-%m-%Y"))
datetimeObject = datetimeObject.replace(tzinfo=None)
dt=datetimeObject-timedelta(days=1)
print(dt.day)
# Out:
# 16-08-2021
# 15

# %%
from datetime import datetime, timedelta
from tzlocal import get_localzone # pip install tzlocal

DAY = timedelta(1)
local_tz = get_localzone()   # get local timezone
now = datetime.now(local_tz) # get timezone-aware datetime object
day_ago = local_tz.normalize(now - DAY) # exactly 24 hours ago, time may differ
naive = now.replace(tzinfo=None) - DAY # same time
yesterday = local_tz.localize(naive, is_dst=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-3c6a7da9a993> in <module>
#       5 local_tz = get_localzone()   # get local timezone
#       6 now = datetime.now(local_tz) # get timezone-aware datetime object
# ----> 7 day_ago = local_tz.normalize(now - DAY) # exactly 24 hours ago, time may differ
#       8 naive = now.replace(tzinfo=None) - DAY # same time
#       9 yesterday = local_tz.localize(naive, is_dst=None)
#
# AttributeError: 'backports.zoneinfo.ZoneInfo' object has no attribute 'normalize'

# %%
dft.iloc[-2:-1]
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 23051     72870271171   270911  25-01-2011                11              5
#
#        Qty  Rate     Tax  total_amt Store_type
# 23051    3  1142  359.73    3785.73   TeleShop

# %%
dft
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:sh000j00000@localhost/Flaskapp", echo=True)
query="select * from modicare;"
df_master=pd.read_sql(query,con=engine)
# Out:
# 2021-08-17 03:23:57,686 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-17 03:23:57,687 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-17 03:23:57,692 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-17 03:23:57,693 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-17 03:23:57,699 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-17 03:23:57,700 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-17 03:23:57,703 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-17 03:23:57,705 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-17 03:23:57,708 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-08-17 03:23:57,710 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-17 03:23:57,712 INFO sqlalchemy.engine.base.Engine DESCRIBE `select * from modicare;`
# 2021-08-17 03:23:57,713 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
json={}
json['namelist']=df_master['Agent Name'].to_list()
json['company']=df_master['Company'].to_list()
json['w_location']=df_master['Working Location'].to_list()
json['b_location']=df_master['Base Location'].to_list()
json['department']=df_master['Department'].to_list()
json['serial']=df_master['S.No.'].to_list()
json['mac']=df_master['MAC User'].to_list()
json['remark']=df_master['Remarks'].to_list()
json['weekend']=df_master['Weekend'].to_list()
json['name']=df_master['Name'].to_list()

# %%
ag_mstr=pd.read_csv("agentmaster.csv")

# %%
count=0
for name in json['namelist']:
    df_ag=ag_mstr[ag_mstr['agentname']==str(name)].copy()
    if df_ag.empty:
        pass
    else:
        count+=1
print(count)
# Out:
# 163

# %%
df_8=pd.read_csv("month8.csv")

# %%
count=0
lst=[]
lst2=[]
lst3=[]
df_88=pd.DataFrame()
for name in json['namelist']:
    df_ag=ag_mstr[ag_mstr['agentname']==str(name)].copy()
    if df_ag.empty:
        pass
    else:
        lst.append(df_ag)
        idd=df_ag['agentid'].to_list()
        if len(idd)>1:
            lst2.append(idd)
        else:
            lst3.append(idd)
        #idd=df_ag['agentid'].values[0]
        for i in idd:
            df_88=df_8[df_8['agentid']==i].copy()
            if df_88.empty:
                print(name)
                pass
            else:
                count+=1
print(count)
print(len(lst))
print(len(lst2))
print(len(lst3))
# Out:
# MCARE-SHAILLY MAINI
# MCARE-AMRITA GHOSH SEN
# MCARE-KRISHNENDU GHOSH
# MCARE-DEBDULAL-LAPTOP
# MCARE-CHAMANDEEP
# MCARE-SANTOSH KUMAR ROUTRAY
# MCARE-RATNESH
# MCARE-TARUN BHARDWAJ
# MCARE-DEEPAKT
# MCARE-PROTEEK CHATTERJEE
# MCARE-PROTEEK CHATTERJEE
# MCARE-NASEEM PUNJ
# Ashish Sahni
# MCARE-SUMA RAJAN
# MCARE-MONICA SINGH
# MCARE-POOJA
# MCARE-SURESH KUMAR
# MCARE-SHEFALI SETH
# MCARE-VASEEM AHAMAD
# MCARE-VASEEM AHAMAD
# MCARE-TARUN KUMAR
# MCARE-SUDHANSHU KUMAR
# MCARE-PRIYA SHARMA
# MCARE-KARAN-LAPTOP
# MCARE-KARAN-LAPTOP
# MCARE-NAFEES AHMAD DESKTOP
# MCARE-NAFEES AHMAD DESKTOP
# MCARE-MALVIKA
# MCARE-MOHITDELL-LAP
# MCARE-PRERNA JAIN
# MCARE-PRERNA JAIN
# MCARE-SHUCHI ARORA
# MCARE-RK KUMAR
# MCARE-SHIKHAR JOY SINGH
# MCARE-KEHAR
# MCARE-ANUPN
# MCARE-SUNIL MISRI
# MCARE-SUNIL MISRI
# MCARE-SUNIL MISRI
# MCARE-SUNIL MISRI
# MCARE-BALVANT
# MCARE-LAVKUSH
# MCARE-SANTOSH TIWARI
# MCARE-SANTOSH TIWARI
# MCARE-PRASHANT PREM
# MCARE-PUNEET
# MCARE-REENA ANTIL
# MCARE-MONIKA
# ...

# %%
# Import the required module for text 
# to speech conversion
from gtts import gTTS
  
# This module is imported so that we can 
# play the converted audio
import os
  
# The text that you want to convert to audio
mytext = 'Welcome to geeksforgeeks!'
  
# Language in which you want to convert
language = 'en'
  
# Passing the text and language to the engine, 
# here we have marked slow=False. Which tells 
# the module that the converted audio should 
# have a high speed
myobj = gTTS(text=mytext, lang=language, slow=False)
  
# Saving the converted audio in a mp3 file named
# welcome 
myobj.save("welcome.mp3")
  
# Playing the converted file
os.system("mpg321 welcome.mp3")
# Out:
# 1

# %%
import json
from dataprofiler import Data, Profiler
from pywaffle import Waffle
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import seaborn as sns
import uuid
from pywaffle import Waffle
from sqlalchemy import create_engine
from dateutil.parser import parse
# Out:
# G:\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
engine = create_engine("mysql+mysqlconnector://root:sh00j0000@localhost/flaskapp", echo=True)
query='select `Date`,`Active Screen Time` from analysis where `Agent Name`="MCARE-AAKASH SIKKA";'
df=pd.read_sql(query,con=engine)
# Out:
# 2021-08-18 00:31:13,260 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-18 00:31:13,261 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-18 00:31:13,266 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-18 00:31:13,267 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-18 00:31:13,271 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-18 00:31:13,273 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-18 00:31:13,277 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-18 00:31:13,278 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-18 00:31:13,281 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-08-18 00:31:13,284 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
# Import Data
#df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')
#df.set_index(['Date'],inplace=True)
# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('Date', 'Active Screen Time', data=df, color='tab:red')

# Decoration
plt.ylim(50, 750)
xtick_location = df.index.tolist()[::12]
xtick_labels = [x[-4:] for x in df.Date.tolist()[::12]]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=0, fontsize=12, horizontalalignment='center', alpha=.7)
plt.yticks(fontsize=12, alpha=.7)
plt.title("Air Passengers Traffic (1949 - 1969)", fontsize=22)
plt.grid(axis='both', alpha=.3)

# Remove borders
plt.gca().spines["top"].set_alpha(0.0)    
plt.gca().spines["bottom"].set_alpha(0.3)
plt.gca().spines["right"].set_alpha(0.0)    
plt.gca().spines["left"].set_alpha(0.3)   
plt.show()

# %%
df1 = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')

# %%
df1
# Out:
#            date  value
# 0    1949-01-01    112
# 1    1949-02-01    118
# 2    1949-03-01    132
# 3    1949-04-01    129
# 4    1949-05-01    121
# ..          ...    ...
# 139  1960-08-01    606
# 140  1960-09-01    508
# 141  1960-10-01    461
# 142  1960-11-01    390
# 143  1960-12-01    432
#
# [144 rows x 2 columns]

# %%
df
# Out:
#     Active Screen Time
# 0               5.7092
# 1               3.1800
# 2               0.6078
# 3               0.8353
# 4               4.5811
# 5               4.6869
# 6               0.0764
# 7               4.7233
# 8               5.1222
# 9               4.9494
# 10              5.2217
# 11              5.0344
# 12              5.7472
# 13              4.5003
# 14              1.1117
# 15              5.4297
# 16              5.3800
# 17              3.5508
# 18              5.5872
# 19              1.3078
# 20              3.3467
# 21              4.7561
# 22              3.8625
# 23              3.7419

# %%
n_bins=40
# Creating distribution
x = df['Active Screen Time']
#y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)



# Creating histogram
N, bins, patches = axs.hist(x, bins = n_bins)

plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')
#plt.savefig('histogram.png',bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Customized histogram')

# %%
plt.figure(figsize=(10,5))
plt.xlim(0,2000)
plt.xlabel('Price')
plt.ylabel('Records')
sns.distplot(df['Active Screen Time'],bins=20,kde=False)
plt.show()

# %%
df
# Out:
#           Date  Active Screen Time
# 0   01-07-2021              5.7092
# 1   02-07-2021              3.1800
# 2   03-07-2021              0.6078
# 3   04-07-2021              0.8353
# 4   05-07-2021              4.5811
# 5   06-07-2021              4.6869
# 6   07-07-2021              0.0764
# 7   08-07-2021              4.7233
# 8   09-07-2021              5.1222
# 9   12-07-2021              4.9494
# 10  13-07-2021              5.2217
# 11  14-07-2021              5.0344
# 12  15-07-2021              5.7472
# 13  16-07-2021              4.5003
# 14  17-07-2021              1.1117
# 15  19-07-2021              5.4297
# 16  20-07-2021              5.3800
# 17  21-07-2021              3.5508
# 18  22-07-2021              5.5872
# 19  27-07-2021              1.3078
# 20  28-07-2021              3.3467
# 21  29-07-2021              4.7561
# 22  30-07-2021              3.8625
# 23  31-07-2021              3.7419

# %%
from datetime import datetime
now_time=datetime.now().time()
time=now_time.strftime('%I_%M_%S')
time
# Out:
# '12_01_16'

# %%
df1['value'].dtype
# Out:
# dtype('int64')

# %%
import traceback

try:
    raise TypeError("Oups!")
except Exception as err:
    traceback.print_tb(err.__traceback__)

# %%
fig=df.plot(kind="line",stacked=False)
plt.title('Company Statistics')
fig.figure.savefig(SAVEPATH+"lines.png",bbox_inches='tight')
plt.close(fig)

# %%
import traceback
a=5
b=0
try:
    print(a/b)
except:
    print(str(traceback.format_exc()))
#print(z)
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-58-d2a9c37ddb70>", line 5, in <module>
#     print(a/b)
# ZeroDivisionError: division by zero

# %%
z
# Out:
# 'Traceback (most recent call last):\n  File "<ipython-input-56-4c6c09dccc1f>", line 5, in <module>\n    print(a/b)\nZeroDivisionError: division by zero\n'

# %%
a=5
b=0
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-38-88cd8d286239> in <module>
#       1 a=5
#       2 b=0
# ----> 3 a/b
#
# ZeroDivisionError: division by zero

# %%
dfexl = dfexl.reindex(['Agent Name','Department','E-Mailid','Location','Working Location','Group Name','Company Tag'], axis=1)
dfmail.rename(columns={"Report Description": "E-Mailid"},inplace=True)
df_s.columns = df_s.columns.str.replace(' ', '')
df_s = df_s.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
dfexl=dfexl.drop(['Agent Id', 'Host Name'], axis = 1)

# %%
dfem=pd.read_excel("TQF.xlsx")

# %%
dfem.index=dfem.index.rename('S.No.')

# %%
dfem=dfem.drop(['S.No.'],axis=1)

# %%
dfml
# Out:
#                        Agent Name                     Name        Department  \
# 0       MCARE-ARUN KUMAR TRIPATHY      Arun Kumar Tripathy             Sales
# 1      MCARE-JAYPRAKASH SUNDARRAY     Jayprakash Sundarray             Sales
# 2       MCARE-DEEPAK RANJAN SAHOO      Deepak Ranjan Sahoo          Training
# 3               MCARE-Bijay Kumar        Bijay Kumar Samal        Operations
# 4             MCARE-SHAILLY MAINI            Shailly Maini  Customer Delight
# ..                            ...                      ...               ...
# 201  MCARE-ANTRIKSHA SHAILESH NAG  Antariksha Shailesh Nag     Sales Support
# 202           MCARE-NIKITA-LAPTOP     Nikita Jagdish Patil          Training
# 203             MCARE-NITIN MHASE              Nitin Mhase             Sales
# 204           MCARE-JAYESH-LAPTOP          Jayesh G Ashara             Sales
# 205         MCARE-ARPITA MAZUMDAR          Arpita Mazumdar          Training
#
# ...

# %%
dfem.rename(columns={"E-Mailid": "Email ID"},inplace=True)

# %%
dfem.columns = dfem.columns.str.strip()
dfem = dfem.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
dfem
# Out:
#                   AgentName                  Name               Department  \
# S.No.
# 1         CB-PALLAVI SEHGAL     CB-PALLAVI SEHGAL                 Training
# 2                  CB-TANVI              CB-TANVI                 Training
# 3        CB-JANET M SOLANKI    CB-JANET M SOLANKI                    Sales
# 4        CB-AMIT KANSAL-CHD    CB-AMIT KANSAL-CHD                    Sales
# 5      CB-MANNGAIHPAU POLLY  CB-MANNGAIHPAU POLLY                 Training
# ...                     ...                   ...                      ...
# 219     CB-NISHANT VIRADIYA   CB-NISHANT VIRADIYA        Retail Operations
# 220          CB-ACHAL MADAN        CB-ACHAL MADAN                      SCM
# 221        CB-RAMESHWAR JHA      CB-RAMESHWAR JHA                      SCM
# 222       CB-SATENDER KUMAR     CB-SATENDER KUMAR  Sourcing & Supply Chain
# 223       TFS-ANUJ MALHOTRA     TFS-ANUJ MALHOTRA       Finance & Accounts
#
# ...

# %%
frames = [dfml,dfem]
result = pd.concat(frames)

# %%
result
# Out:
#                      Agent Name                  Name  \
# 0     MCARE-ARUN KUMAR TRIPATHY   Arun Kumar Tripathy
# 1    MCARE-JAYPRAKASH SUNDARRAY  Jayprakash Sundarray
# 2     MCARE-DEEPAK RANJAN SAHOO   Deepak Ranjan Sahoo
# 3             MCARE-Bijay Kumar     Bijay Kumar Samal
# 4           MCARE-SHAILLY MAINI         Shailly Maini
# ..                          ...                   ...
# 218         CB-NISHANT VIRADIYA   CB-NISHANT VIRADIYA
# 219              CB-ACHAL MADAN        CB-ACHAL MADAN
# 220            CB-RAMESHWAR JHA      CB-RAMESHWAR JHA
# 221           CB-SATENDER KUMAR     CB-SATENDER KUMAR
# 222           TFS-ANUJ MALHOTRA     TFS-ANUJ MALHOTRA
#
#                   Department                            Email ID  \
# 0                      Sales  aruntripathy-modicare@modi-ent.com
# 1                      Sales    jayprakash-modicare@modi-ent.com
# 2                   Training        dsahoo-modicare@modi-ent.com
# ...

# %%
dfem.reset_index(inplace=True)

# %%
dfem.
# Out:
#      S.No.            Agent Name                  Name  \
# 0        1     CB-PALLAVI SEHGAL     CB-PALLAVI SEHGAL
# 1        2              CB-TANVI              CB-TANVI
# 2        3    CB-JANET M SOLANKI    CB-JANET M SOLANKI
# 3        4    CB-AMIT KANSAL-CHD    CB-AMIT KANSAL-CHD
# 4        5  CB-MANNGAIHPAU POLLY  CB-MANNGAIHPAU POLLY
# ..     ...                   ...                   ...
# 218    219   CB-NISHANT VIRADIYA   CB-NISHANT VIRADIYA
# 219    220        CB-ACHAL MADAN        CB-ACHAL MADAN
# 220    221      CB-RAMESHWAR JHA      CB-RAMESHWAR JHA
# 221    222     CB-SATENDER KUMAR     CB-SATENDER KUMAR
# 222    223     TFS-ANUJ MALHOTRA     TFS-ANUJ MALHOTRA
#
#                   Department                    Email ID Working Location  \
# 0                   Training     psehgal-cb@modi-ent.com          ACADEMY
# 1                   Training       twahi-cb@modi-ent.com          ACADEMY
# 2                      Sales      jsingh-cb@modi-ent.com        AHMEDABAD
# ...

# %%
dfem.rename(columns={"MACUser": "MAC User"},inplace=True)

# %%
dfem.columns=dfem.columns.str.strip()

# %%
dfem = dfem.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
dfem
# Out:
#                  Agent Name                  Name               Department  \
# S.No.
# 1         CB-PALLAVI SEHGAL     CB-PALLAVI SEHGAL                 Training
# 2                  CB-TANVI              CB-TANVI                 Training
# 3        CB-JANET M SOLANKI    CB-JANET M SOLANKI                    Sales
# 4        CB-AMIT KANSAL-CHD    CB-AMIT KANSAL-CHD                    Sales
# 5      CB-MANNGAIHPAU POLLY  CB-MANNGAIHPAU POLLY                 Training
# ...                     ...                   ...                      ...
# 219     CB-NISHANT VIRADIYA   CB-NISHANT VIRADIYA        Retail Operations
# 220          CB-ACHAL MADAN        CB-ACHAL MADAN                      SCM
# 221        CB-RAMESHWAR JHA      CB-RAMESHWAR JHA                      SCM
# 222       CB-SATENDER KUMAR     CB-SATENDER KUMAR  Sourcing & Supply Chain
# 223       TFS-ANUJ MALHOTRA     TFS-ANUJ MALHOTRA       Finance & Accounts
#
# ...

# %%
dfml=pd.read_sql("select * from modicare", con=engine)
# Out:
# 2021-08-19 18:13:20,174 INFO sqlalchemy.engine.base.Engine DESCRIBE `select * from modicare`
# 2021-08-19 18:13:20,176 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:13:20,550 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2021-08-19 18:13:20,565 INFO sqlalchemy.engine.base.OptionEngine select * from modicare
# 2021-08-19 18:13:20,567 INFO sqlalchemy.engine.base.OptionEngine {}

# %%
print(dfml.columns)
print(dfem.columns)
# Out:
# Index(['Agent Name', 'Name', 'Department', 'Email ID', 'Working Location',
#        'Base Location', 'Remarks', 'Company', 'MAC User', 'Weekend'],
#       dtype='object')
# Index(['Agent Name', 'Name', 'Department', 'Email ID', 'Working Location',
#        'Base Location', 'Remarks', 'Company', 'MAC User', 'Weekend'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:sh00j0000@localhost/Flaskapp", echo=True)
#df_attend=pd.read_csv("attendence.csv")
tablename="master_sheet"
result.to_sql(tablename,chunksize=1000, con=engine, index=False, if_exists='append')
# Out:
# 2021-08-19 18:23:17,303 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-08-19 18:23:17,304 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:23:17,611 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-08-19 18:23:17,612 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:23:17,635 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2021-08-19 18:23:17,637 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:23:17,694 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2021-08-19 18:23:17,695 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:23:17,698 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2021-08-19 18:23:17,699 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-19 18:23:17,702 INFO sqlalchemy.engine.base.Engine DESCRIBE `master_sheet`
# 2021-08-19 18:23:17,703 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
result.to_csv("master_sheet.csv",index=False)

# %%
dfem['Name']=dfem['Agent Name']

# %%
dfem['Base Location']=dfem.apply(lambda x: x['Base Location'].replace('Head Office','HO'),axis=1)

# %%
dfem.index=dfem.index+1
dfem
# Out:
#                  Agent Name                  Name               Department  \
# S.No.
# 1         CB-PALLAVI SEHGAL     CB-PALLAVI SEHGAL                 Training
# 2                  CB-TANVI              CB-TANVI                 Training
# 3        CB-JANET M SOLANKI    CB-JANET M SOLANKI                    Sales
# 4        CB-AMIT KANSAL-CHD    CB-AMIT KANSAL-CHD                    Sales
# 5      CB-MANNGAIHPAU POLLY  CB-MANNGAIHPAU POLLY                 Training
# ...                     ...                   ...                      ...
# 219     CB-NISHANT VIRADIYA   CB-NISHANT VIRADIYA        Retail Operations
# 220          CB-ACHAL MADAN        CB-ACHAL MADAN                      SCM
# 221        CB-RAMESHWAR JHA      CB-RAMESHWAR JHA                      SCM
# 222       CB-SATENDER KUMAR     CB-SATENDER KUMAR  Sourcing & Supply Chain
# 223       TFS-ANUJ MALHOTRA     TFS-ANUJ MALHOTRA       Finance & Accounts
#
# ...

# %%
dfml
# Out:
#                        Agent Name                     Name        Department  \
# 0       MCARE-ARUN KUMAR TRIPATHY      Arun Kumar Tripathy             Sales
# 1      MCARE-JAYPRAKASH SUNDARRAY     Jayprakash Sundarray             Sales
# 2       MCARE-DEEPAK RANJAN SAHOO      Deepak Ranjan Sahoo          Training
# 3               MCARE-Bijay Kumar        Bijay Kumar Samal        Operations
# 4             MCARE-SHAILLY MAINI            Shailly Maini  Customer Delight
# ..                            ...                      ...               ...
# 201  MCARE-ANTRIKSHA SHAILESH NAG  Antariksha Shailesh Nag     Sales Support
# 202           MCARE-NIKITA-LAPTOP     Nikita Jagdish Patil          Training
# 203             MCARE-NITIN MHASE              Nitin Mhase             Sales
# 204           MCARE-JAYESH-LAPTOP          Jayesh G Ashara             Sales
# 205         MCARE-ARPITA MAZUMDAR          Arpita Mazumdar          Training
#
# ...

# %%
a='Head Office'
a=a.replace('Head Office','HO')
a
# Out:
# 'HO'

# %%
a=[0.0006,0.0045]
min(a)
# Out:
# 0.0006

# %%
lu=[
           0.0022,       
            0.0033,         
           0.0022,         
          0.0017,         
          0.0017,         
           0.0139]
min(lu)
# Out:
# 0.0017

# %%
df_wb=pd.read_csv("malfun.csv")

# %%
df_webusage=df_wb[df_wb['isProductive']==False]

# %%
df_webusage
# Out:
#                    Unnamed: 0  agentid category                 date  \
# 50  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 51  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 52  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 53  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 54  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 55  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
# 56  2021-07-26 18:30:00+00:00     1123      NaN  1627324200000000000
#
#     duration  isProductive                                                url
# 50    0.0144         False  %252Fc%253A%252Fusers%252Fbbakshi%252Fappdata%...
# 51    0.0022         False  %252Fc%253A%252Fusers%252Fbbakshi%252Fappdata%...
# 52    0.0033         False  %252Fc%253A%252Fusers%252Fbbakshi%252Fappdata%...
# 53    0.0022         False  %252Fc%253A%252Fusers%252Fbbakshi%252Fappdata%...
# ...

# %%
df_webusage.drop_duplicates(inplace=True)
#print(df_webusage)
df_webusage['url']=df_webusage['url'].fillna('none')
df_webusage['length']=df_webusage[['url']].apply(lambda x: len(x['url']),axis=1)
#df_webusage.drop(df_webusage[df_webusage['length'] > 30].index, inplace = True)
df_webusage['url']=df_webusage.apply(lambda x: x['url'][:29] if x['length']>30 else x['url'],axis=1)
df_wb=df_webusage[['url','duration']]
temp=df_wb.groupby(by=['url'],as_index=False)['duration'].sum()
temp.sort_values(['duration'], ascending=False, inplace=True)
filepath="/home/centos/iassist/bot/pdfreport/webusage_unpro/{path}".format(path=str(uuid.uuid1())+".png")
plt.figure(figsize=(8, 8))
plt.rc('ytick', labelsize=13)
plot=sns.barplot(data=temp.head(8),x='duration',y='url',palette='rocket_r')
# fig=plot.get_figure()
# fig.savefig(filepath,bbox_inches='tight')
# plt.close(fig)
plt.show()
# Out:
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
len(df_webusage['url'].values[0])
# Out:
# 29

# %%
x = df_wb.groupby('url')['duration'].mean().sort_values().tail(15)
x.plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)

# %%
a=3
a>3
# Out:
# False

# %%
dfp=pd.read_csv("month7.csv")

# %%
ab=dfp.loc[:0]

# %%
ab.iloc[-2:-1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, agentid, agentname, appProductiveTime, appUnproductiveTime, browserProductiveTime, browserUnProductiveTime, date, loginTime1, loginTime2, logoutTime1, logoutTime2, onScreenTime, productiveTime, screenLockTime, sessionBreakTime, systemUpTime, totalBrowserActiveTime, totalInactiveTime, totalNonBrowserActiveTime, unProductiveTime]
# Index: []
#
# [0 rows x 21 columns]

# %%
str(dfp['loginTime1'].values[0])[:10]
# Out:
# '1.62510951'

# %%
a='jatinchauhan'
a[-4:]
# Out:
# 'uhan'

# %%
dfp=pd.read_csv("midwest.csv")

# %%
dfp
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 327  3045   WALWORTH    WI  0.032     75000  2343.750000     72747       454
# 328  3046   WASHBURN    WI  0.050     13772   275.440000     13585        25
# 329  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 330  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 331  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
sns.countplot(dfp['state'])

# %%
plt.pie(dfp['state'].value_counts(),startangle=90,autopct='%.3f',labels=a,shadow=True)
plt.savefig("piee.png",bbox_inches='tight')

# %%
dfp['state'].value_counts().plot.bar()
plt.savefig("barrr.png")

# %%
plt.scatter(dfp.index,dfp['popblack'])
plt.show()

# %%
plt.hist(dfp['popblack'])
# Out:
# (array([270.,  31.,  10.,   5.,   8.,   3.,   0.,   3.,   0.,   2.]),
#  array([   0. ,  634.2, 1268.4, 1902.6, 2536.8, 3171. , 3805.2, 4439.4,
#         5073.6, 5707.8, 6342. ]),
#  <a list of 10 Patch objects>)

# %%
from

# %%
sns

# %%
import numpy as np
a=list(np.unique(dfp['state']))
a
# Out:
# ['IL', 'IN', 'MI', 'OH', 'WI']

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:sh00j0000@localhost/flaskapp", echo=True)

# %%
query="select * from modicare;"
df=pd.read_sql(query, con=engine)
# Out:
# 2021-08-23 21:43:24,502 INFO sqlalchemy.engine.base.Engine DESCRIBE `select * from modicare;`
# 2021-08-23 21:43:24,503 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-23 21:43:24,620 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2021-08-23 21:43:24,623 INFO sqlalchemy.engine.base.OptionEngine select * from modicare;
# 2021-08-23 21:43:24,624 INFO sqlalchemy.engine.base.OptionEngine {}

# %%
list(np.unique(df['Department']))
# Out:
# ['Business Development',
#  'COO Office',
#  'Customer Delight',
#  'Finance & Accounts',
#  'Growth Office',
#  'HR & Admin',
#  'Information Technology',
#  'International Business & Legal',
#  'Marketing',
#  'NPD',
#  'Operations',
#  'Sales',
#  'Sales Support',
#  'Training']

# %%
dfm=pd.read_csv("MCARE_master.csv")

# %%
dfm
# Out:
#      S.No.                    Agent Name                     Name  \
# 0        1     MCARE-ARUN KUMAR TRIPATHY      Arun Kumar Tripathy
# 1        2    MCARE-JAYPRAKASH SUNDARRAY     Jayprakash Sundarray
# 2        3     MCARE-DEEPAK RANJAN SAHOO      Deepak Ranjan Sahoo
# 3        4             MCARE-Bijay Kumar        Bijay Kumar Samal
# 4        5           MCARE-SHAILLY MAINI            Shailly Maini
# ..     ...                           ...                      ...
# 201    201  MCARE-ANTRIKSHA SHAILESH NAG  Antariksha Shailesh Nag
# 202    202           MCARE-NIKITA-LAPTOP     Nikita Jagdish Patil
# 203    203             MCARE-NITIN MHASE              Nitin Mhase
# 204    204           MCARE-JAYESH-LAPTOP          Jayesh G Ashara
# 205    205         MCARE-ARPITA MAZUMDAR          Arpita Mazumdar
#
#            Department                            Email ID Working Location  \
# 0               Sales  aruntripathy-modicare@modi-ent.com        Berhampur
# ...

# %%
dfm.drop(dfm[dfm['Agent Name']=='Nitin Chauhan'].index,inplace=True)

# %%
dfm[dfm['Agent Name']=='Nitin Chauhan']
# Out:
# Empty DataFrame
# Columns: [S.No., Agent Name, Name, Department, Email ID, Working Location, Base Location, Remarks, Company, MAC User, Weekend]
# Index: []

# %%
new_df=pd.DataFrame({'Email ID':['srikanth-modicare@modi-ent.com']},index=dfm[dfm['Agent Name']=='Srikanth N'].index)

# %%
dfm.update(new_df)

# %%
dfm[dfm['Agent Name']=='Srikanth N']
# Out:
#      S.No.  Agent Name        Name Department                        Email ID  \
# 174    174  Srikanth N  Srikanth N   Training  srikanth-modicare@modi-ent.com
#
#     Working Location Base Location Remarks           Company MAC User Weekend
# 174        Bangalore  South Region    none  Modicare Limited     none  Sunday

# %%
dfm
# Out:
#      S.No.                    Agent Name                     Name  \
# 0        1     MCARE-ARUN KUMAR TRIPATHY      Arun Kumar Tripathy
# 1        2    MCARE-JAYPRAKASH SUNDARRAY     Jayprakash Sundarray
# 2        3     MCARE-DEEPAK RANJAN SAHOO      Deepak Ranjan Sahoo
# 3        4             MCARE-Bijay Kumar        Bijay Kumar Samal
# 4        5           MCARE-SHAILLY MAINI            Shailly Maini
# ..     ...                           ...                      ...
# 201    201  MCARE-ANTRIKSHA SHAILESH NAG  Antariksha Shailesh Nag
# 202    202           MCARE-NIKITA-LAPTOP     Nikita Jagdish Patil
# 203    203             MCARE-NITIN MHASE              Nitin Mhase
# 204    204           MCARE-JAYESH-LAPTOP          Jayesh G Ashara
# 205    205         MCARE-ARPITA MAZUMDAR          Arpita Mazumdar
#
#            Department                            Email ID Working Location  \
# 0               Sales  aruntripathy-modicare@modi-ent.com        Berhampur
# ...

# %%
dfm.drop(['S.No.'],axis=1,inplace=True)

# %%
dfm[dfm['Agent Name']=='Nitin Chauhan']
# Out:
# Empty DataFrame
# Columns: [Agent Name, Name, Department, Email ID, Working Location, Base Location, Remarks, Company, MAC User, Weekend]
# Index: []

# %%
frames=[dfm,dfv]
result=pd.concat(frames)

# %%
result.to_csv('Mcare_mastersheet.csv')

# %%
dfv=pd.read_excel("MCARE_update.xlsx")

# %%
dfv.index=dfv.index.rename("S.No.")

# %%
dfv.reset_index()
# Out:
#     S.No.             Agent Name               Name              Department  \
# 0       0    MCARE-NITIN CHAUHAN      Nitin Chauhan  Information Technology
# 1       1        MCARE-DEEPKAMAL         Deep Kamal  Information Technology
# 2       2            ARUN-LAPTOP        Arun Bansal  Information Technology
# 3       3             UPENDRA-IT      Upendra Singh  Information Technology
# 4       4           SATYAWANS-IT     Satyawan Singh  Information Technology
# 5       5         MCARE-CHANCHAL    Chanchal Bharti  Information Technology
# 6       6       MCARE-CREDO-WEB1     Sanjay Chauhan  Information Technology
# 7       7       MCARE-CREDO-WEB2        Kiran Mehta  Information Technology
# 8       8         MCARE-RAJAN-IT          Rajan Jha  Information Technology
# 9       9                 RAM-IT         Ram Shukla  Information Technology
# 10     10          MCARE-ARIHANT     Arihant Gurung               Marketing
# ...

# %%
df = pd.DataFrame({'A': ['a', 'b', 'c'],
                   'B': ['x', 'y', 'z']})
new_df = pd.DataFrame({'C': ['d', 'e','m']})
df.update(new_df)

# %%
lst=['Operations','Marketing']

# %%
result['Department'].isin(lst)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# Name: Department, Length: 220, dtype: bool

# %%
result.loc[result['Department'].isin(lst)]
# Out:
#                      Agent Name                  Name  Department  \
# 3             MCARE-Bijay Kumar     Bijay Kumar Samal  Operations
# 14           MCARE-GAUTAM GUPTA          Gautam Gupta  Operations
# 15        MCARE-TAPASKHAN-LAPTO      Tapas Kumar Khan  Operations
# 22          MCARE-VISHWA DEEPAK         Vishwa Deepak  Operations
# 86               MCARE-RUCHI-HO           Ruchi Kumar   Marketing
# 87                  MCARE-SMITA           Smita Sahoo   Marketing
# 88        MCARE-KASHISH HUSSAIN       Kashish Hussain   Marketing
# 89                 MCARE-ANKITA         Ankita Dhawan   Marketing
# 90           MCARE-KARAN-LAPTOP          Karan Munjal   Marketing
# 91               MCARE-JASINDER       Jasinder Bhatia   Marketing
# 92                     Manoj A.              Manoj A.   Marketing
# 93   MCARE-NAFEES AHMAD DESKTOP          Nafees Ahmad   Marketing
# 94                MCARE-SANDEEP         Sandeep Tomar   Marketing
# ...

# %%
gn=pd.read_csv("agentmaster2.csv")

# %%
lstr=[]
namels=result['Agent Name'].to_list()

# %%
result[result['Agent Name']=='MCARE-AAKASH SIKKA']['Email ID'].to_list()
# Out:
# ['aakash-modicare@modi-ent.com']

# %%
flat_list = []
for i in namels:
    lstr.append(gn[gn['agentname']==str(i)]['agentid'].to_list())
lstr    
# for sublist in t:
#     for item in sublist:
#         flat_list.append(item)
# Out:
# [[607],
#  [297],
#  [667],
#  [935],
#  [598],
#  [885, 610],
#  [1032],
#  [612],
#  [912],
#  [],
#  [],
#  [595],
#  [606, 608],
#  [564],
#  [301],
#  [879],
#  [],
#  [890],
#  [904],
#  [869, 860],
#  [623],
#  [666],
#  [446],
#  [599],
#  [605],
#  [597],
#  [617],
#  [1039],
#  [1023, 969],
#  [672],
#  [],
#  [],
#  [842],
#  [251],
#  [248],
#  [905],
#  [207],
#  [441],
#  [955],
#  [640],
#  [938],
#  [220],
#  [939],
#  [559, 815],
#  [],
#  [894],
#  [1110],
#  [1245, 941],
#  [896],
#  [],
#  [280, 282, 258],
#  [272, 551],
#  [861],
#  [858],
#  [231, 341],
#  [881],
#  [270, 853],
#  [990],
#  [1016, 936],
#  [],
#  [919],
#  [950],
#  [],
#  [],
#  [523],
#  [206, 442],
#  [542, 219],
#  [],
#  [533, 278],
#  [],
#  [756],
#  [],
#  [215, 573],
#  [214],
#  [211],
#  [212],
#  [880],
#  [],
#  [],
#  [],
#  [],
#  [534],
#  [209],
#  [909],
#  [968],
#  [862],
#  [1065],
#  [239],
#  [961],
#  [246, 670, 892],
#  [925],
#  [],
#  [788, 790, 728],
#  [937],
# ...

# %%
mnth.loc[mnth['agentid'].isin(flat_list)]
# Out:
#                      Unnamed: 0  agentid              agentname  \
# 2     2021-07-31 18:30:00+00:00     1009           MCARE-HIMANI
# 6     2021-07-31 18:30:00+00:00     1016            MCARE-POOJA
# 11    2021-07-31 18:30:00+00:00     1022         MCARE-ANUBHUTI
# 12    2021-07-31 18:30:00+00:00     1023          MCARE-RATNESH
# 18    2021-07-31 18:30:00+00:00     1032     MCARE-SHRABANTIDEY
# ...                         ...      ...                    ...
# 8283  2021-08-15 18:30:00+00:00      955    MCARE-SURENDRA_Ind1
# 8288  2021-08-15 18:30:00+00:00      961           MCARE-ANKITA
# 8289  2021-08-15 18:30:00+00:00      962  MCARE-VARINDA-RAJOURI
# 8293  2021-08-15 18:30:00+00:00      968             MCARE-TARA
# 8305  2021-08-15 18:30:00+00:00      990           MCARE-SUSHIL
#
#       appProductiveTime  appUnproductiveTime  browserProductiveTime  \
# 2                1.3106               0.5425                 0.0261
# ...

# %%
mnth['nn']="ff00"
mnth
# Out:
#                      Unnamed: 0  agentid            agentname  \
# 0     2021-07-31 18:30:00+00:00      100   CB-SPANJAL%20BASSI
# 1     2021-07-31 18:30:00+00:00     1003             MF-SUMIT
# 2     2021-07-31 18:30:00+00:00     1009         MCARE-HIMANI
# 3     2021-07-31 18:30:00+00:00     1012     CB-VINAY%20KUMAR
# 4     2021-07-31 18:30:00+00:00     1013   CB-FAIZUR%20REHMAN
# ...                         ...      ...                  ...
# 8305  2021-08-15 18:30:00+00:00      990         MCARE-SUSHIL
# 8306  2021-08-15 18:30:00+00:00      991   CB-ANKIT%20PANCHAL
# 8307  2021-08-15 18:30:00+00:00      993    CB-GAUTAM%20ARORA
# 8308  2021-08-15 18:30:00+00:00      996  CB-VIKASH%20DESKTOP
# 8309  2021-08-15 18:30:00+00:00      999  CB-PANKAJ%20KHANEJA
#
#       appProductiveTime  appUnproductiveTime  browserProductiveTime  \
# 0                0.0000               0.0000                 0.0000
# 1                0.0000               0.0000                 0.0000
# ...

# %%
for sublist in lstr:
    for item in sublist:
        flat_list.append(item)

# %%
flat_list
# Out:
# 237

# %%
mnth=pd.read_csv("month8.csv")

# %%
df
# Out:
#    A  B
# 0  a  x
# 1  b  y
# 2  c  z

# %%
v="CB-D.%20AROCKIA%20ANNA%20JEGAN"
v.replace("%20"," ")
# Out:
# 'CB-D. AROCKIA ANNA JEGAN'

# %%
df_sliced=pd.read_csv("full_month_8.csv")

# %%
df_sliced
# Out:
#        level_0  index                 Unnamed: 0  agentid  \
# 0            0      0  2021-07-31 18:30:00+00:00      100
# 1            1      1  2021-07-31 18:30:00+00:00     1003
# 2            2      2  2021-07-31 18:30:00+00:00     1009
# 3            3      3  2021-07-31 18:30:00+00:00     1012
# 4            4      4  2021-07-31 18:30:00+00:00     1013
# ...        ...    ...                        ...      ...
# 11947    11947  11947  2021-08-22 18:30:00+00:00      990
# 11948    11948  11948  2021-08-22 18:30:00+00:00      991
# 11949    11949  11949  2021-08-22 18:30:00+00:00      993
# 11950    11950  11950  2021-08-22 18:30:00+00:00      996
# 11951    11951  11951  2021-08-22 18:30:00+00:00      999
#
#                  agentname  appProductiveTime  appUnproductiveTime  \
# 0       CB-SPANJAL%20BASSI             0.0000               0.0000
# 1                 MF-SUMIT             0.0000               0.0000
# ...

# %%
type(df_sliced['date'].values[0])
# Out:
# str

# %%
import calendar
from datetime import datetime, date, timedelta

# %%
df_sliced = df_sliced.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
#df_x['Dates']=df_x.apply(lambda x: datetime.fromtimestamp(int(x['date'][:10])).strftime('%d-%m-%Y'),axis=1)
df_sliced.reset_index(inplace=True)
df_sliced['date']=df_sliced.apply(lambda x: datetime.fromtimestamp(int(str(x['date'])[:10])).strftime('%d-%m-%Y'),axis=1)
df_sliced = df_sliced.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
print("sliced")
df_sliced['Weekday']=df_sliced.apply(lambda x: calendar.day_name[datetime.strptime(x['date'],'%d-%m-%Y').weekday()],axis=1)
print("weekday")
df_sliced['UnproductiveTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['unProductiveTime']))+datetime.min),axis=1)
print("unprod")
df_sliced['productiveTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['productiveTime']))+datetime.min),axis=1)
print("prod")
df_sliced['IdleTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['screenLockTime']))+datetime.min),axis=1)
print("idletime")
df_sliced['TotalTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['systemUpTime']))+datetime.min),axis=1)
print("totaltime")
df_sliced['TotalActiveTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['onScreenTime']))+datetime.min),axis=1)
print("totalactive")
df_sliced['OfflineTime']=df_sliced.apply(lambda x: x['totalInactiveTime']+x['sessionBreakTime'],axis=1)
print("offile")
df_sliced['OfflineTime(Readable)']=df_sliced.apply(lambda x: "{:%Hh %Mm}".format(timedelta(hours=float(x['OfflineTime']))+datetime.min),axis=1)
print("offlineread")
#df_sliced['Firstlogin']=df_sliced.apply(lambda x: "NaT" if x['loginTime1']=='NA'else datetime.fromtimestamp(int(str(x['loginTime1'])[:10])).strftime("%I:%M %p"),axis=1)
#print("firstlog")
#df_sliced['lastlogin']=df_sliced.apply(lambda x: "NaT" if x['loginTime2']=='NA'else datetime.fromtimestamp(int(str(x['loginTime2'])[:10])).strftime("%I:%M %p"),axis=1)
#print("lastlog")
#df_sliced['Firstlogout']=df_sliced.apply(lambda x: "NaT" if x['logoutTime1']=='NA'else datetime.fromtimestamp(int(str(x['logoutTime1'])[:10])).strftime("%I:%M %p"),axis=1)
#print("firstlogout")
#df_sliced['lastlogout']=df_sliced.apply(lambda x: "NaT" if x['logoutTime2']=='NA'else datetime.fromtimestamp(int(str(x['logoutTime2'])[:10])).strftime("%I:%M %p"),axis=1)
#print("lastlogout")
filterd_e=df_sliced.filter(['agentname','date','Weekday','UnproductiveTime(Readable)','productiveTime(Readable)','IdleTime(Readable)','TotalTime(Readable)','TotalActiveTime(Readable)','OfflineTime(Readable)'],axis=1)
# Out:
# sliced
# weekday
# unprod
# prod
# idletime
# totaltime
# totalactive
# offile
# offlineread

# %%
filterd_e[filterd_e['agentname']=='MCARE-ARUN%20KUMAR%20TRIPATHY']
# Out:
#                            agentname        date    Weekday  \
# 308    MCARE-ARUN%20KUMAR%20TRIPATHY  01-08-2021     Sunday
# 826    MCARE-ARUN%20KUMAR%20TRIPATHY  02-08-2021     Monday
# 1344   MCARE-ARUN%20KUMAR%20TRIPATHY  03-08-2021    Tuesday
# 1862   MCARE-ARUN%20KUMAR%20TRIPATHY  04-08-2021  Wednesday
# 2380   MCARE-ARUN%20KUMAR%20TRIPATHY  05-08-2021   Thursday
# 2898   MCARE-ARUN%20KUMAR%20TRIPATHY  06-08-2021     Friday
# 3416   MCARE-ARUN%20KUMAR%20TRIPATHY  07-08-2021   Saturday
# 3934   MCARE-ARUN%20KUMAR%20TRIPATHY  08-08-2021     Sunday
# 4452   MCARE-ARUN%20KUMAR%20TRIPATHY  09-08-2021     Monday
# 4970   MCARE-ARUN%20KUMAR%20TRIPATHY  10-08-2021    Tuesday
# 5489   MCARE-ARUN%20KUMAR%20TRIPATHY  11-08-2021  Wednesday
# 6010   MCARE-ARUN%20KUMAR%20TRIPATHY  12-08-2021   Thursday
# 6532   MCARE-ARUN%20KUMAR%20TRIPATHY  13-08-2021     Friday
# 7054   MCARE-ARUN%20KUMAR%20TRIPATHY  14-08-2021   Saturday
# 7581   MCARE-ARUN%20KUMAR%20TRIPATHY  15-08-2021     Sunday
# ...

# %%
a="MCARE-PRAKASH-DESKTOP"
a.startswith("MCARE-PRAKASH-DESK")
# Out:
# True
